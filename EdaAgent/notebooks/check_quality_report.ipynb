# %% [markdown]
# # Reportes De Calidad

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/quality_report.csv')

# %%
df
# Out:
#                columna   nulos  no_nulos  porcentaje_nulos
# 0          estacion_id       0    762376          0.000000
# 1      nombre_estacion       0    762376          0.000000
# 2               estado       0    762376          0.000000
# 3            municipio       0    762376          0.000000
# 4   situacion_estacion       0    762376          0.000000
# 5            organismo       0    762376          0.000000
# 6              cve_omm  720440     41936         94.499302
# 7              latitud       0    762376          0.000000
# 8             longitud       0    762376          0.000000
# 9         altitud_msnm       0    762376          0.000000
# 10               fecha       0    762376          0.000000
# 11              precip       0    762376          0.000000
# 12                evap       0    762376          0.000000
# 13                tmax       0    762376          0.000000
# 14                tmin       0    762376          0.000000
# ...
